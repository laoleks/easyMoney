# %% [markdown]
# # ACTIVIDADES FINALES MÓDULO 1

# %% [markdown]
# Para hacer estas actividades finales usaremos un Dataset que contiene las notas en examenes y homework de un grupo de alumnos. Usa la siguiente url en la función de pandas pd.read_csv para obtener el dataframe: https://raw.githubusercontent.com/realpython/materials/master/pandas-gradebook-project/data/hw_exam_grades.csv

# %% [markdown]
# 1. Importa la librería de Pandas

# %%
import pandas as pd

# %% [markdown]
# 2. Importa el dataframe de la url mencionada en la introducción y guárdalo en una variable llamada df

# %%
df = pd.read_csv("https://raw.githubusercontent.com/realpython/materials/master/pandas-gradebook-project/data/hw_exam_grades.csv")

# %% [markdown]
# 3. Aplica la función head para ver las primeras líneas de nuestro dataframe

# %%
df.head()
# Out:
#   First Name  Last Name       SID  Homework 1  Homework 1 - Max Points  \
# 0      Aaron     Lester  axl60952        68.0                       80
# 1       Adam     Cooper  amc28428        80.0                       80
# 2       Alec      Curry  axc64717        69.0                       80
# 3  Alexander  Rodriguez  akr14831        50.0                       80
# 4      Amber    Daniels  axd11293        54.0                       80
#
#   Homework 1 - Submission Time  Homework 2  Homework 2 - Max Points  \
# 0    2019-08-29 08:56:02-07:00          74                       80
# 1    2019-08-29 08:56:02-07:00          78                       80
# 2    2019-08-29 08:56:02-07:00          76                       80
# 3    2019-08-29 08:56:02-07:00          54                       80
# 4    2019-08-29 08:56:02-07:00          57                       80
#
#   Homework 2 - Submission Time  Homework 3  ...  \
# 0    2019-09-05 08:56:02-07:00          77  ...
# 1    2019-09-05 08:56:02-07:00          78  ...
# 2    2019-09-05 08:56:02-07:00          66  ...
# 3    2019-09-05 08:56:02-07:00          74  ...
# 4    2019-09-05 08:56:02-07:00          77  ...
#
#    Homework 10 - Submission Time Exam 1  Exam 1 - Max Points  \
# 0      2019-10-31 08:56:02-07:00     79                  100
# 1      2019-10-31 08:56:02-07:00     65                  100
# 2      2019-10-31 08:56:02-07:00     65                  100
# 3      2019-10-31 08:56:02-07:00     97                  100
# 4      2019-10-31 08:56:02-07:00     68                  100
#
#     Exam 1 - Submission Time Exam 2  Exam 2 - Max Points  \
# 0  2019-10-08 12:30:07-07:00     63                  100
# 1  2019-10-08 12:30:07-07:00     63                  100
# 2  2019-10-08 12:30:07-07:00     78                  100
# 3  2019-10-08 12:30:07-07:00     97                  100
# 4  2019-10-08 12:30:07-07:00     95                  100
#
#     Exam 2 - Submission Time Exam 3  Exam 3 - Max Points  \
# 0  2019-11-08 12:30:07-07:00     68                  100
# 1  2019-11-08 12:30:07-07:00     90                  100
# 2  2019-11-08 12:30:07-07:00     83                  100
# 3  2019-11-08 12:30:07-07:00     81                  100
# 4  2019-11-08 12:30:07-07:00     88                  100
#
#     Exam 3 - Submission Time
# 0  2019-12-08 12:30:07-07:00
# 1  2019-12-08 12:30:07-07:00
# 2  2019-12-08 12:30:07-07:00
# 3  2019-12-08 12:30:07-07:00
# 4  2019-12-08 12:30:07-07:00
#
# [5 rows x 42 columns]

# %% [markdown]
# 4. Trabajaremos solo con algunas de las columnas de df. Crea un dataframe llamado gradebook que contenga las siguientes columnas de df: First Name, Last Name, SID, Homework 1, Homework 2, Homework 3, Exam 1, Exam 2
#
# Aplica la función .head() a gradebook para verificar que esté correcto

# %%
gradebook = df[['First Name', 'Last Name', 'SID', 'Homework 1', 'Homework 2', 'Homework 3', 'Exam 1', 'Exam 2']]

# %%
gradebook.head()
# Out:
#   First Name  Last Name       SID  Homework 1  Homework 2  Homework 3  Exam 1  \
# 0      Aaron     Lester  axl60952        68.0          74          77      79
# 1       Adam     Cooper  amc28428        80.0          78          78      65
# 2       Alec      Curry  axc64717        69.0          76          66      65
# 3  Alexander  Rodriguez  akr14831        50.0          54          74      97
# 4      Amber    Daniels  axd11293        54.0          57          77      68
#
#    Exam 2
# 0      63
# 1      63
# 2      78
# 3      97
# 4      95

# %% [markdown]
# A partir de ahora, a no ser que se especificara la contrario, trabajaremos siempre con el dataframe gradebook.

# %% [markdown]
# 5. Encuentra cuántas filas y columnas tiene gradebook mediante la función shape

# %%
gradebook.shape
# Out:
# (150, 8)

# %% [markdown]
# 6. Obtén la información básica del dataframe mediante la función info. Fíjate en si hay alguna columna con elementos nulos y de que tipo son los datos de cada columna.

# %%
gradebook.info
# Out:
# <bound method DataFrame.info of     First Name   Last Name       SID  Homework 1  Homework 2  Homework 3  \
# 0        Aaron      Lester  axl60952        68.0          74          77
# 1         Adam      Cooper  amc28428        80.0          78          78
# 2         Alec       Curry  axc64717        69.0          76          66
# 3    Alexander   Rodriguez  akr14831        50.0          54          74
# 4        Amber     Daniels  axd11293        54.0          57          77
# ..         ...         ...       ...         ...         ...         ...
# 145     Travis  Washington  txw75701        64.0          67          56
# 146       Troy     Raymond  tbr17292        50.0          59          79
# 147   Victoria        Boyd  vkb66346        58.0          61          75
# 148    William      Daniel  wad63934        48.0          60          72
# 149      Woody     Barrera  wxb12345        55.0          62          73
#
#      Exam 1  Exam 2
# 0        79      63
# 1        65      63
# 2        65      78
# 3        97      97
# 4        68      95
# ..      ...     ...
# 145      94      74
# 146      91      67
# 147      68      93
# 148      84      91
# 149      86      62
#
# [150 rows x 8 columns]>

# %% [markdown]
# 7. Vamos a limpiar los nombres de las columnas: pon todos los nombres en minúsculas y que no contengan espacios.

# %%
gradebook['First Name'] = gradebook['First Name'].str.lower().replace(' ','')
# Out:
# <ipython-input-8-bbf9cf1b0188>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gradebook['First Name'] = gradebook['First Name'].str.lower().replace(' ','')

# %%
gradebook.head()
# Out:
#   First Name  Last Name       SID  Homework 1  Homework 2  Homework 3  Exam 1  \
# 0      aaron     Lester  axl60952        68.0          74          77      79
# 1       adam     Cooper  amc28428        80.0          78          78      65
# 2       alec      Curry  axc64717        69.0          76          66      65
# 3  alexander  Rodriguez  akr14831        50.0          54          74      97
# 4      amber    Daniels  axd11293        54.0          57          77      68
#
#    Exam 2
# 0      63
# 1      63
# 2      78
# 3      97
# 4      95

# %% [markdown]
# 8. Aplica la función drop_duplicates a gradebook para eliminar duplicados si los hay, luego imprime la shape del nuevo dataframe y mira si se han borrado registros. Recuerda especificar el parámetro que hace que los cambios se lleven a cabo en el mismo dataframe. ¿Había duplicados?

# %%
gradebook.drop_duplicates(inplace=True)
# Out:
# <ipython-input-15-0f4e8079b816>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gradebook.drop_duplicates(inplace=True)

# %%
gradebook.shape
# Out:
# (150, 8)

# %% [markdown]
# 9. Mira que columnas de gradebook tienen nulos y cuántos registros nulos tienen mediante la función isnull

# %%
gradebook.isnull().sum()
# Out:
# First Name    0
# Last Name     0
# SID           0
# Homework 1    1
# Homework 2    0
# Homework 3    0
# Exam 1        0
# Exam 2        0
# dtype: int64

# %% [markdown]
# 10. En el caso de que haya algun valor nulo en la nota de algun examen o homework, reemplaza este nulo que sería un no entregado por un 0. Comprueba que lo has hecho bien volviendo a mirar los nulos de gradebook.

# %%
gradebook['Homework 1'].fillna('no entregado', inplace=True)
# Out:
# <ipython-input-14-0e6d09eba743>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gradebook['Homework 1'].fillna('no entregado', inplace=True)

# %%
gradebook.isnull().sum()
# Out:
# First Name    0
# Last Name     0
# SID           0
# Homework 1    0
# Homework 2    0
# Homework 3    0
# Exam 1        0
# Exam 2        0
# dtype: int64

# %% [markdown]
# 11. En nuestro dataframe, para cada tarea tenemos una columna con la nota que sacó el alumno y otra columna que nos indica el máximo de puntuación que se podía sacar en esa tarea.
#
# Hagamos que todas las notas estén sobre 10. Para ello crea una función que dada una nota y el máximo que se podia sacar en esa tarea, divida la nota entre el máximo y lo multiplique por 10 para sacar la nota sobre 10.
#
# Luego, aplica esta función a cada una de las tareas y guarda la nota obtenida para cada tarea en una columna llamada nombretarea_s10. Por ejemplo homework1_s10 o exam1_s10.

# %%
#SOLUCION 1. porque este no funciona?
def notas(x,y):
  result = x/y*10
  return result

df['nombretarea_s10'] = df.apply(notas, args=(df['Homework 1'], df['Homework 1 - Max Points'])) #porque este no funciona?
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-b70b7db03f0c> in <cell line: 5>()
#       3   return result
#       4
# ----> 5 df['nombretarea_s10'] = df.apply(notas, args=(df['Homework 1'], df['Homework 1 - Max Points'])) #porque este no funciona?
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, **kwargs)
#    9566             kwargs=kwargs,
#    9567         )
# -> 9568         return op.apply().__finalize__(self, method="apply")
#    9569
#    9570     def applymap(
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/apply.py in apply(self)
#     762             return self.apply_raw()
#     763
# --> 764         return self.apply_standard()
#     765
#     766     def agg(self):
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/apply.py in apply_standard(self)
#     889
#     890     def apply_standard(self):
# --> 891         results, res_index = self.apply_series_generator()
#     892
#     893         # wrap results
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/apply.py in apply_series_generator(self)
#     905             for i, v in enumerate(series_gen):
#     906                 # ignore SettingWithCopy here in case the user mutates
# --> 907                 results[i] = self.f(v)
#     908                 if isinstance(results[i], ABCSeries):
#     909                     # If we have a view on v, we need to make a copy because
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/apply.py in f(x)
#     140
#     141             def f(x):
# --> 142                 return func(x, *args, **kwargs)
#     143
#     144         else:
#
# TypeError: notas() takes 2 positional arguments but 3 were given

# %%
#SOLUCION2

def notas(x,y):
  result = round(x/y*10)
  return result

gradebook['nombretarea_s10'] = notas(df['Homework 1'], df['Homework 1 - Max Points'])
# Out:
# <ipython-input-19-605c75d27c92>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gradebook['nombretarea_s10'] = notas(df['Homework 1'], df['Homework 1 - Max Points'])

# %%
gradebook['homework1_s10'] = notas(df['Homework 1'], df['Homework 1 - Max Points'])
# Out:
# <ipython-input-20-4635b33192fd>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gradebook['homework1_s10'] = notas(df['Homework 1'], df['Homework 1 - Max Points'])

# %%
gradebook['homework2_s10'] = notas(df['Homework 2'], df['Homework 2 - Max Points'])
# Out:
# <ipython-input-21-61481bf00973>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gradebook['homework2_s10'] = notas(df['Homework 2'], df['Homework 2 - Max Points'])

# %%
gradebook['homework3_s10'] = notas(df['Homework 3'], df['Homework 3 - Max Points'])
# Out:
# <ipython-input-22-984159c2d962>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gradebook['homework3_s10'] = notas(df['Homework 3'], df['Homework 3 - Max Points'])

# %%
gradebook['exam1_s10'] = notas(df['Exam 1'], df['Exam 1 - Max Points'])
# Out:
# <ipython-input-23-01cb9cbc38fb>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gradebook['exam1_s10'] = notas(df['Exam 1'], df['Exam 1 - Max Points'])

# %%
gradebook['exam2_s10'] = notas(df['Exam 2'], df['Exam 2 - Max Points'])
# Out:
# <ipython-input-24-b9a3eb19de5c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gradebook['exam2_s10'] = notas(df['Exam 2'], df['Exam 2 - Max Points'])

# %%
gradebook
# Out:
#     First Name   Last Name       SID Homework 1  Homework 2  Homework 3  \
# 0        aaron      Lester  axl60952       68.0          74          77
# 1         adam      Cooper  amc28428       80.0          78          78
# 2         alec       Curry  axc64717       69.0          76          66
# 3    alexander   Rodriguez  akr14831       50.0          54          74
# 4        amber     Daniels  axd11293       54.0          57          77
# ..         ...         ...       ...        ...         ...         ...
# 145     travis  Washington  txw75701       64.0          67          56
# 146       troy     Raymond  tbr17292       50.0          59          79
# 147   victoria        Boyd  vkb66346       58.0          61          75
# 148    william      Daniel  wad63934       48.0          60          72
# 149      woody     Barrera  wxb12345       55.0          62          73
#
#      Exam 1  Exam 2  nombretarea_s10  homework1_s10  homework2_s10  \
# 0        79      63              8.0            8.0            9.0
# 1        65      63             10.0           10.0           10.0
# 2        65      78              9.0            9.0           10.0
# 3        97      97              6.0            6.0            7.0
# 4        68      95              7.0            7.0            7.0
# ..      ...     ...              ...            ...            ...
# 145      94      74              8.0            8.0            8.0
# 146      91      67              6.0            6.0            7.0
# 147      68      93              7.0            7.0            8.0
# 148      84      91              6.0            6.0            8.0
# 149      86      62              7.0            7.0            8.0
#
#      homework3_s10  exam1_s10  exam2_s10
# 0             10.0        8.0        6.0
# 1             10.0        6.0        6.0
# 2              8.0        6.0        8.0
# 3              9.0       10.0       10.0
# 4             10.0        7.0       10.0
# ..             ...        ...        ...
# 145            7.0        9.0        7.0
# 146           10.0        9.0        7.0
# 147            9.0        7.0        9.0
# 148            9.0        8.0        9.0
# 149            9.0        9.0        6.0
#
# [150 rows x 14 columns]

# %% [markdown]
# Usa las columnas con las notas calculadas sobre 10 para responder las preguntas siguientes:

# %% [markdown]
# 12. Cuántos alumnos han sacado menos de un 7 en el Homework3?

# %%
gradebook_examen_7 = len(gradebook[gradebook['homework3_s10']<7])

# %%
gradebook_examen_7
# Out:
# 19

# %%
gradebook[gradebook['homework3_s10'] < 7].count()

# %%
gradebook_examen_7['First Name'].count()
# Out:
# 19

# %%
gradebook[gradebook['homework3_s10'] < 7].groupby('homework3_s10').count()
# Out:
#                First Name  Last Name  SID  Homework 1  Homework 2  Homework 3  \
# homework3_s10
# 6.0                    19         19   19          19          19          19
#
#                Exam 1  Exam 2  nombretarea_s10  homework1_s10  homework2_s10  \
# homework3_s10
# 6.0                19      19               19             19             19
#
#                exam1_s10  exam2_s10
# homework3_s10
# 6.0                   19         19

# %% [markdown]
# 19

# %% [markdown]
# 13. Cuántos alumnos sacaron un 10 sobre 10 en el examen 1? Y cuál es la media del examen 2, de los alumnos que sacaron un 10 en el examen 1?

# %%
gradebook_examen_10 = gradebook[gradebook['exam1_s10'] == 10]

# %%
gradebook_examen_10['First Name'].count()
# Out:
# 16

# %%
gradebook_examen_10
# Out:
#     First Name  Last Name       SID    Homework 1  Homework 2  Homework 3  \
# 3    alexander  Rodriguez  akr14831          50.0          54          74
# 6          amy      White  alw07647          71.0          60          72
# 21     bradley      Bryan  bxb28023          55.0          65          63
# 23     brandon     Flores  bcf26283          62.0          52          77
# 31       carol      Reyes  cxr98775          75.0          80          66
# 49       emily     Dudley  eed42850          53.0          80          62
# 50       emily    Houston  edh14938          54.0          60          56
# 53     heather       Webb  hxw92728          56.0          48          60
# 80     kristin   Petersen  ksp17362          49.0          77          75
# 101    michele      Jones  mxj54725          67.0          61          65
# 105     nicole       Mann  nxm87406          73.0          53          80
# 107     nicole  Patterson  njp08545          66.0          66          55
# 109      paige       King  pmk49230          61.0          61          61
# 118     robert   Johnston  rsj94156          74.0          64          64
# 130      stacy    Johnson  smj00936          74.0          55          60
# 144      traci      Joyce  txj12345  no entregado          77          58
#
#      Exam 1  Exam 2  nombretarea_s10  homework1_s10  homework2_s10  \
# 3        97      97              6.0            6.0            7.0
# 6        99      95              9.0            9.0            8.0
# 21       96      82              7.0            7.0            8.0
# 23       96      93              8.0            8.0            6.0
# 31       99      91              9.0            9.0           10.0
# 49       96      73              7.0            7.0           10.0
# 50      100      78              7.0            7.0            8.0
# 53      100      61              7.0            7.0            6.0
# 80       97      68              6.0            6.0           10.0
# 101     100      82              8.0            8.0            8.0
# 105      99      85              9.0            9.0            7.0
# 107      96      91              8.0            8.0            8.0
# 109      97      99              8.0            8.0            8.0
# 118      98      61              9.0            9.0            8.0
# 130      96      80              9.0            9.0            7.0
# 144     100      84              NaN            NaN           10.0
#
#      homework3_s10  exam1_s10  exam2_s10
# 3              9.0       10.0       10.0
# 6              9.0       10.0       10.0
# 21             8.0       10.0        8.0
# 23            10.0       10.0        9.0
# 31             8.0       10.0        9.0
# 49             8.0       10.0        7.0
# 50             7.0       10.0        8.0
# 53             8.0       10.0        6.0
# 80             9.0       10.0        7.0
# 101            8.0       10.0        8.0
# 105           10.0       10.0        8.0
# 107            7.0       10.0        9.0
# 109            8.0       10.0       10.0
# 118            8.0       10.0        6.0
# 130            8.0       10.0        8.0
# 144            7.0       10.0        8.0

# %%
gradebook_examen_10['exam2_s10'].mean()
# Out:
# 8.1875

# %%
gradebook_examen_10['exam2_s10'].median()
# Out:
# 8.0

# %% [markdown]
# 14. Crea una columna que contenga la media de las 3 homeworks para cada alumno y llamala homework_mean y otra que contenga la media de los 2 examenes para cada alumno y llamala exam_mean. Recuerda que la media se calcula como la suma de los elementos entre el número de elementos

# %%
gradebook['homework_mean'] = (gradebook['homework1_s10']+gradebook['homework2_s10']+gradebook['homework3_s10'])/3
# Out:
# <ipython-input-33-43bcb39b1d58>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gradebook['homework_mean'] = (gradebook['homework1_s10']+gradebook['homework2_s10']+gradebook['homework3_s10'])/3

# %%
gradebook['exam_mean'] = (gradebook['exam1_s10']+gradebook['exam2_s10'])/2
# Out:
# <ipython-input-34-5c79fec224c6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gradebook['exam_mean'] = (gradebook['exam1_s10']+gradebook['exam2_s10'])/2

# %%
gradebook
# Out:
#     First Name   Last Name       SID Homework 1  Homework 2  Homework 3  \
# 0        aaron      Lester  axl60952       68.0          74          77
# 1         adam      Cooper  amc28428       80.0          78          78
# 2         alec       Curry  axc64717       69.0          76          66
# 3    alexander   Rodriguez  akr14831       50.0          54          74
# 4        amber     Daniels  axd11293       54.0          57          77
# ..         ...         ...       ...        ...         ...         ...
# 145     travis  Washington  txw75701       64.0          67          56
# 146       troy     Raymond  tbr17292       50.0          59          79
# 147   victoria        Boyd  vkb66346       58.0          61          75
# 148    william      Daniel  wad63934       48.0          60          72
# 149      woody     Barrera  wxb12345       55.0          62          73
#
#      Exam 1  Exam 2  nombretarea_s10  homework1_s10  homework2_s10  \
# 0        79      63              8.0            8.0            9.0
# 1        65      63             10.0           10.0           10.0
# 2        65      78              9.0            9.0           10.0
# 3        97      97              6.0            6.0            7.0
# 4        68      95              7.0            7.0            7.0
# ..      ...     ...              ...            ...            ...
# 145      94      74              8.0            8.0            8.0
# 146      91      67              6.0            6.0            7.0
# 147      68      93              7.0            7.0            8.0
# 148      84      91              6.0            6.0            8.0
# 149      86      62              7.0            7.0            8.0
#
#      homework3_s10  exam1_s10  exam2_s10  homework_mean  exam_mean
# 0             10.0        8.0        6.0       9.000000        7.0
# 1             10.0        6.0        6.0      10.000000        6.0
# 2              8.0        6.0        8.0       9.000000        7.0
# 3              9.0       10.0       10.0       7.333333       10.0
# 4             10.0        7.0       10.0       8.000000        8.5
# ..             ...        ...        ...            ...        ...
# 145            7.0        9.0        7.0       7.666667        8.0
# 146           10.0        9.0        7.0       7.666667        8.0
# 147            9.0        7.0        9.0       8.000000        8.0
# 148            9.0        8.0        9.0       7.666667        8.5
# 149            9.0        9.0        6.0       8.000000        7.5
#
# [150 rows x 16 columns]

# %% [markdown]
# 15. Haz un scatter plot que relacione homework_mean con examen_mean, ves alguna relacion interesante?
# Recuerda importar la libreria matplotlib.pyplot

# %%
import matplotlib.pyplot as plt

# %%
gradebook.plot(kind='scatter', x='homework_mean', y='exam_mean', title='homework vs examen');
